# %%
path = r"C:\Users\Niitro_musics\Documents\Image-Line\FL Studio\Settings\Hardware\a\script.py"

# %%
with open(path,'w') as file:
    file.write(f" f = \' hello \'")

# %%
a = open('./HandToMidi.txt', 'w')

# %%
a.write('he')
# Out:
# 2

# %%
a.write('llo')
# Out:
# 3

# %%
a=[1,2,3,4,6,6]
a
# Out:
# [1, 2, 3, 4, 6, 6]

# %%
a*
# Out:
#   Cell In[25], line 1
#     a*
#       ^
# SyntaxError: invalid syntax

# %%
print(*a)
# Out:
# 1 2 3 4 6 6
